# %% [markdown]
# # Deep learning for computer vision
#
#
# This notebook will teach you to build and train convolutional networks for image recognition. Brace yourselves.

# %% [markdown]
# # CIFAR dataset
# This week, we shall focus on the image recognition problem on cifar10 dataset
# * 60k images of shape 3x32x32
# * 10 different classes: planes, dogs, cats, trucks, etc.
#
# <img src="cifar10.jpg" style="width:80%">

# %%
# when running in colab, un-comment this
# !wget https://raw.githubusercontent.com/yandexdataschool/Practical_DL/fall19/week03_convnets/cifar.py

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
import numpy as np
from cifar import load_cifar10
X_train, y_train, X_val, y_val, X_test, y_test = load_cifar10("cifar_data")

class_names = np.array(['airplane', 'automobile', 'bird', 'cat', 'deer',
                        'dog', 'frog', 'horse', 'ship', 'truck'])

print(X_train.shape,y_train.shape)
# Out:
# Dataset not found. Downloading...
# (40000, 3, 32, 32) (40000,)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=[12,10])
for i in range(12):
    plt.subplot(3,4,i+1)
    plt.xlabel(class_names[y_train[i]])
    plt.imshow(np.transpose(X_train[i],[1,2,0]))

# %% [markdown]
# # Building a network
#
# Simple neural networks with layers applied on top of one another can be implemented as `torch.nn.Sequential` - just add a list of pre-built modules and let it train.

# %%
import torch, torch.nn as nn
import torch.nn.functional as F

# a special module that converts [batch, channel, w, h] to [batch, units]
class Flatten(nn.Module):
    def forward(self, input):
        return input.view(input.size(0), -1)

# %% [markdown]
# Let's start with a dense network for our baseline:

# %%
model = nn.Sequential()

# reshape from "images" to flat vectors
model.add_module('flatten', Flatten())

# dense "head"
model.add_module('dense1', nn.Linear(3 * 32 * 32, 64))
model.add_module('dense1_relu', nn.ReLU())
model.add_module('dense2_logits', nn.Linear(64, 10)) # logits for 10 classes

# %% [markdown]
# As in our basic tutorial, we train our model with negative log-likelihood aka crossentropy.

# %%
def compute_loss(X_batch, y_batch):
    X_batch = torch.as_tensor(X_batch, dtype=torch.float32)
    y_batch = torch.as_tensor(y_batch, dtype=torch.int64)
    logits = model(X_batch)
    return F.cross_entropy(logits, y_batch).mean()

# %%
# example
compute_loss(X_train[:5], y_train[:5])
# Out:
# tensor(2.2999, grad_fn=<MeanBackward0>)

# %% [markdown]
# ### Training on minibatches
# * We got 40k images, that's way too many for a full-batch SGD. Let's train on minibatches instead
# * Below is a function that splits the training sample into minibatches

# %%
# An auxilary function that returns mini-batches for neural network training
def iterate_minibatches(X, y, batchsize):
    indices = np.random.permutation(np.arange(len(X)))
    for start in range(0, len(indices), batchsize):
        ix = indices[start: start + batchsize]
        yield X[ix], y[ix]

# %%
opt = torch.optim.SGD(model.parameters(), lr=0.01)

train_loss = []
val_accuracy = []

# %%
import time
num_epochs = 100 # total amount of full passes over training data
batch_size = 50  # number of samples processed in one SGD iteration

for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    for X_batch, y_batch in iterate_minibatches(X_train, y_train, batch_size):
        # train on batch
        loss = compute_loss(X_batch, y_batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.data.numpy())
        
    # And a full pass over the validation data:
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in iterate_minibatches(X_val, y_val, batch_size):
        logits = model(torch.as_tensor(X_batch, dtype=torch.float32))
        y_pred = logits.max(1)[1].data.numpy()
        val_accuracy.append(np.mean(y_batch == y_pred))

    
    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss[-len(X_train) // batch_size :])))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy[-len(X_val) // batch_size :]) * 100))
# Out:
# Epoch 1 of 100 took 1.226s
#   training loss (in-iteration): 	2.037497
#   validation accuracy: 			33.58 %
# Epoch 2 of 100 took 1.287s
#   training loss (in-iteration): 	1.862067
#   validation accuracy: 			36.30 %
# Epoch 3 of 100 took 1.316s
#   training loss (in-iteration): 	1.790842
#   validation accuracy: 			38.14 %
# Epoch 4 of 100 took 1.162s
#   training loss (in-iteration): 	1.740021
#   validation accuracy: 			40.45 %
# Epoch 5 of 100 took 1.169s
#   training loss (in-iteration): 	1.699394
#   validation accuracy: 			41.62 %
# Epoch 6 of 100 took 1.173s
#   training loss (in-iteration): 	1.667004
#   validation accuracy: 			42.42 %
# Epoch 7 of 100 took 1.158s
#   training loss (in-iteration): 	1.637031
#   validation accuracy: 			42.07 %
# Epoch 8 of 100 took 1.171s
#   training loss (in-iteration): 	1.613054
#   validation accuracy: 			43.41 %
# Epoch 9 of 100 took 1.173s
#   training loss (in-iteration): 	1.592862
#   validation accuracy: 			44.07 %
# Epoch 10 of 100 took 1.155s
#   training loss (in-iteration): 	1.570545
#   validation accuracy: 			44.67 %
# Epoch 11 of 100 took 1.280s
#   training loss (in-iteration): 	1.554044
#   validation accuracy: 			44.32 %
# Epoch 12 of 100 took 1.216s
#   training loss (in-iteration): 	1.538683
#   validation accuracy: 			46.18 %
# Epoch 13 of 100 took 1.163s
#   training loss (in-iteration): 	1.522963
#   validation accuracy: 			45.69 %
# Epoch 14 of 100 took 1.360s
#   training loss (in-iteration): 	1.510608
#   validation accuracy: 			46.68 %
# Epoch 15 of 100 took 1.195s
#   training loss (in-iteration): 	1.498661
#   validation accuracy: 			46.66 %
# Epoch 16 of 100 took 1.247s
#   training loss (in-iteration): 	1.488004
#   validation accuracy: 			45.88 %
# Epoch 17 of 100 took 1.187s
#   training loss (in-iteration): 	1.479536
#   validation accuracy: 			47.48 %
# Epoch 18 of 100 took 1.247s
#   training loss (in-iteration): 	1.467209
#   validation accuracy: 			44.82 %
# Epoch 19 of 100 took 1.184s
#   training loss (in-iteration): 	1.457164
#   validation accuracy: 			46.84 %
# Epoch 20 of 100 took 1.187s
#   training loss (in-iteration): 	1.449097
#   validation accuracy: 			47.29 %
# Epoch 21 of 100 took 1.168s
#   training loss (in-iteration): 	1.441805
#   validation accuracy: 			46.71 %
# Epoch 22 of 100 took 1.252s
#   training loss (in-iteration): 	1.433586
#   validation accuracy: 			47.81 %
# Epoch 23 of 100 took 1.187s
#   training loss (in-iteration): 	1.425297
#   validation accuracy: 			48.23 %
# Epoch 24 of 100 took 1.229s
#   training loss (in-iteration): 	1.418804
#   validation accuracy: 			47.27 %
# Epoch 25 of 100 took 1.224s
#   training loss (in-iteration): 	1.411345
#   validation accuracy: 			47.73 %
# Epoch 26 of 100 took 1.181s
#   training loss (in-iteration): 	1.403601
#   validation accuracy: 			47.14 %
# Epoch 27 of 100 took 1.247s
#   training loss (in-iteration): 	1.397606
#   validation accuracy: 			47.80 %
# Epoch 28 of 100 took 1.227s
#   training loss (in-iteration): 	1.392019
#   validation accuracy: 			48.75 %
# Epoch 29 of 100 took 1.226s
#   training loss (in-iteration): 	1.386869
#   validation accuracy: 			48.66 %
# Epoch 30 of 100 took 1.286s
#   training loss (in-iteration): 	1.380122
#   validation accuracy: 			48.29 %
# Epoch 31 of 100 took 1.226s
#   training loss (in-iteration): 	1.373478
#   validation accuracy: 			48.23 %
# Epoch 32 of 100 took 1.223s
#   training loss (in-iteration): 	1.366849
#   validation accuracy: 			48.68 %
# Epoch 33 of 100 took 1.168s
#   training loss (in-iteration): 	1.361736
#   validation accuracy: 			48.86 %
# Epoch 34 of 100 took 1.213s
#   training loss (in-iteration): 	1.355541
#   validation accuracy: 			48.54 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/bj/_vsd3m557t1f_thrrlbwhjn80000gn/T/ipykernel_8733/212679189.py in <cell line: 5>()
#      10         # train on batch
#      11         loss = compute_loss(X_batch, y_batch)
# ---> 12         loss.backward()
#      13         opt.step()
#      14         opt.zero_grad()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     394                 create_graph=create_graph,
#     395                 inputs=inputs)
# --> 396         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     397
#     398     def register_hook(self, hook):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     171     # some Python versions print out the first line of a multi-line function
#     172     # calls in the traceback and some print out the last line
# --> 173     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %% [markdown]
# Don't wait for full 100 epochs. You can interrupt training after 5-20 epochs once validation accuracy stops going up.
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ### Final test

# %%
model.train(False) # disable dropout / use averages for batch_norm
test_batch_acc = []
for X_batch, y_batch in iterate_minibatches(X_test, y_test, 500):
    logits = model(torch.as_tensor(X_batch, dtype=torch.float32))
    y_pred = logits.max(1)[1].data.numpy()
    test_batch_acc.append(np.mean(y_batch == y_pred))

test_accuracy = np.mean(test_batch_acc)
    
print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_accuracy * 100))

if test_accuracy * 100 > 95:
    print("Double-check, than consider applying for NIPS'17. SRSly.")
elif test_accuracy * 100 > 90:
    print("U'r freakin' amazin'!")
elif test_accuracy * 100 > 80:
    print("Achievement unlocked: 110lvl Warlock!")
elif test_accuracy * 100 > 70:
    print("Achievement unlocked: 80lvl Warlock!")
elif test_accuracy * 100 > 60:
    print("Achievement unlocked: 70lvl Warlock!")
elif test_accuracy * 100 > 50:
    print("Achievement unlocked: 60lvl Warlock!")
else:
    print("We need more magic! Follow instructons below")
# Out:
# Final results:
#   test accuracy:		49.00 %
# We need more magic! Follow instructons below

# %% [markdown]
# ## Task I: small convolution net
# ### First step
#
# Let's create a mini-convolutional network with roughly such architecture:
# * Input layer
# * 3x3 convolution with 10 filters and _ReLU_ activation
# * 2x2 pooling (or set previous convolution stride to 3)
# * Flatten
# * Dense layer with 100 neurons and _ReLU_ activation
# * 10% dropout
# * Output dense layer.
#
#
# __Convolutional layers__ in torch are just like all other layers, but with a specific set of parameters:
#
# __`...`__
#
# __`model.add_module('conv1', nn.Conv2d(in_channels=3, out_channels=10, kernel_size=3)) # convolution`__
#
# __`model.add_module('pool1', nn.MaxPool2d(2)) # max pooling 2x2`__
#
# __`...`__
#
#
# Once you're done (and compute_loss no longer raises errors), train it with __Adam__ optimizer with default params (feel free to modify the code above).
#
# If everything is right, you should get at least __50%__ validation accuracy.

# %%
model = nn.Sequential()

# convolution
model.add_module('conv1', nn.Conv2d(in_channels=3, out_channels=10, kernel_size=3))
model.add_module('conv1_relu', nn.ReLU())
model.add_module('pool1', nn.MaxPool2d(2))

# reshape from "images" to flat vectors
model.add_module('flatten', Flatten())

# dense "head"
model.add_module('dense1', nn.Linear(2250, 100))
model.add_module('dense1_relu', nn.ReLU())

model.add_module('dropout1', nn.Dropout(0.1))

# dense "tail"
model.add_module('dense2', nn.Linear(100, 64))
model.add_module('dense2_relu', nn.ReLU())

model.add_module('dense3_logits', nn.Linear(64, 10)) # logits for 10 classes

# %%
opt = torch.optim.SGD(model.parameters(), lr=0.01)

train_loss = []
val_accuracy = []

# %%
import time
num_epochs = 100 # total amount of full passes over training data
batch_size = 50  # number of samples processed in one SGD iteration

for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    for X_batch, y_batch in iterate_minibatches(X_train, y_train, batch_size):
        # train on batch
        loss = compute_loss(X_batch, y_batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.data.numpy())
        
    # And a full pass over the validation data:
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in iterate_minibatches(X_val, y_val, batch_size):
        logits = model(torch.as_tensor(X_batch, dtype=torch.float32))
        y_pred = logits.max(1)[1].data.numpy()
        val_accuracy.append(np.mean(y_batch == y_pred))

    
    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss[-len(X_train) // batch_size :])))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy[-len(X_val) // batch_size :]) * 100))
# Out:
# Epoch 1 of 100 took 5.988s
#   training loss (in-iteration): 	2.231394
#   validation accuracy: 			27.69 %
# Epoch 2 of 100 took 5.718s
#   training loss (in-iteration): 	1.986811
#   validation accuracy: 			32.49 %
# Epoch 3 of 100 took 6.650s
#   training loss (in-iteration): 	1.892097
#   validation accuracy: 			34.95 %
# Epoch 4 of 100 took 6.401s
#   training loss (in-iteration): 	1.817841
#   validation accuracy: 			37.40 %
# Epoch 5 of 100 took 7.473s
#   training loss (in-iteration): 	1.739905
#   validation accuracy: 			40.18 %
# Epoch 6 of 100 took 7.558s
#   training loss (in-iteration): 	1.659844
#   validation accuracy: 			42.07 %
# Epoch 7 of 100 took 5.907s
#   training loss (in-iteration): 	1.580294
#   validation accuracy: 			44.94 %
# Epoch 8 of 100 took 7.066s
#   training loss (in-iteration): 	1.512010
#   validation accuracy: 			44.10 %
# Epoch 9 of 100 took 5.781s
#   training loss (in-iteration): 	1.465302
#   validation accuracy: 			49.62 %
# Epoch 10 of 100 took 6.749s
#   training loss (in-iteration): 	1.416765
#   validation accuracy: 			48.85 %
# Epoch 11 of 100 took 7.634s
#   training loss (in-iteration): 	1.371636
#   validation accuracy: 			52.44 %
# Epoch 12 of 100 took 8.026s
#   training loss (in-iteration): 	1.330881
#   validation accuracy: 			53.28 %
# Epoch 13 of 100 took 8.329s
#   training loss (in-iteration): 	1.299499
#   validation accuracy: 			54.52 %
# Epoch 14 of 100 took 7.639s
#   training loss (in-iteration): 	1.265588
#   validation accuracy: 			54.90 %
# Epoch 15 of 100 took 7.487s
#   training loss (in-iteration): 	1.238126
#   validation accuracy: 			55.05 %
# Epoch 16 of 100 took 9.132s
#   training loss (in-iteration): 	1.211265
#   validation accuracy: 			56.17 %
# Epoch 17 of 100 took 7.321s
#   training loss (in-iteration): 	1.187047
#   validation accuracy: 			56.24 %
# Epoch 18 of 100 took 7.107s
#   training loss (in-iteration): 	1.163373
#   validation accuracy: 			57.42 %
# Epoch 19 of 100 took 7.947s
#   training loss (in-iteration): 	1.138788
#   validation accuracy: 			57.32 %
# Epoch 20 of 100 took 7.677s
#   training loss (in-iteration): 	1.122109
#   validation accuracy: 			58.08 %
# Epoch 21 of 100 took 7.922s
#   training loss (in-iteration): 	1.101557
#   validation accuracy: 			58.10 %
# Epoch 22 of 100 took 7.071s
#   training loss (in-iteration): 	1.081224
#   validation accuracy: 			58.83 %
# Epoch 23 of 100 took 8.181s
#   training loss (in-iteration): 	1.060779
#   validation accuracy: 			59.34 %
# Epoch 24 of 100 took 7.711s
#   training loss (in-iteration): 	1.043895
#   validation accuracy: 			59.85 %
# Epoch 25 of 100 took 8.468s
#   training loss (in-iteration): 	1.022366
#   validation accuracy: 			59.19 %
# Epoch 26 of 100 took 7.887s
#   training loss (in-iteration): 	1.002905
#   validation accuracy: 			60.05 %
# Epoch 27 of 100 took 7.804s
#   training loss (in-iteration): 	0.984153
#   validation accuracy: 			60.21 %
# Epoch 28 of 100 took 7.556s
#   training loss (in-iteration): 	0.968069
#   validation accuracy: 			60.66 %
# Epoch 29 of 100 took 7.838s
#   training loss (in-iteration): 	0.955585
#   validation accuracy: 			59.77 %
# Epoch 30 of 100 took 7.606s
#   training loss (in-iteration): 	0.933602
#   validation accuracy: 			60.27 %
# Epoch 31 of 100 took 7.284s
#   training loss (in-iteration): 	0.916510
#   validation accuracy: 			59.82 %
# Epoch 32 of 100 took 7.239s
#   training loss (in-iteration): 	0.899879
#   validation accuracy: 			59.45 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/bj/_vsd3m557t1f_thrrlbwhjn80000gn/T/ipykernel_8733/212679189.py in <cell line: 5>()
#       9     for X_batch, y_batch in iterate_minibatches(X_train, y_train, batch_size):
#      10         # train on batch
# ---> 11         loss = compute_loss(X_batch, y_batch)
#      12         loss.backward()
#      13         opt.step()
#
# /var/folders/bj/_vsd3m557t1f_thrrlbwhjn80000gn/T/ipykernel_8733/1749192806.py in compute_loss(X_batch, y_batch)
#       2     X_batch = torch.as_tensor(X_batch, dtype=torch.float32)
#       3     y_batch = torch.as_tensor(y_batch, dtype=torch.int64)
# ----> 4     logits = model(X_batch)
#       5     return F.cross_entropy(logits, y_batch).mean()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     455
#     456     def forward(self, input: Tensor) -> Tensor:
# --> 457         return self._conv_forward(input, self.weight, self.bias)
#     458
#     459 class Conv3d(_ConvNd):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     451                             weight, bias, self.stride,
#     452                             _pair(0), self.dilation, self.groups)
# --> 453         return F.conv2d(input, weight, bias, self.stride,
#     454                         self.padding, self.dilation, self.groups)
#     455
#
# KeyboardInterrupt:

# %% [markdown]
# ### Final test (convolution)

# %%
model.train(False) # disable dropout / use averages for batch_norm
test_batch_acc = []
for X_batch, y_batch in iterate_minibatches(X_test, y_test, 500):
    logits = model(torch.as_tensor(X_batch, dtype=torch.float32))
    y_pred = logits.max(1)[1].data.numpy()
    test_batch_acc.append(np.mean(y_batch == y_pred))

test_accuracy = np.mean(test_batch_acc)
    
print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_accuracy * 100))

if test_accuracy * 100 > 95:
    print("Double-check, than consider applying for NIPS'17. SRSly.")
elif test_accuracy * 100 > 90:
    print("U'r freakin' amazin'!")
elif test_accuracy * 100 > 80:
    print("Achievement unlocked: 110lvl Warlock!")
elif test_accuracy * 100 > 70:
    print("Achievement unlocked: 80lvl Warlock!")
elif test_accuracy * 100 > 60:
    print("Achievement unlocked: 70lvl Warlock!")
elif test_accuracy * 100 > 50:
    print("Achievement unlocked: 60lvl Warlock!")
else:
    print("We need more magic! Follow instructons below")
# Out:
# Final results:
#   test accuracy:		60.09 %
# Achievement unlocked: 70lvl Warlock!

# %% [markdown]
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# __Hint:__ If you don't want to compute shapes by hand, just plug in any shape (e.g. 1 unit) and run compute_loss. You will see something like this:
#
# __`RuntimeError: size mismatch, m1: [5 x 1960], m2: [1 x 64] at /some/long/path/to/torch/operation`__
#
# See the __1960__ there? That's your actual input shape.
#
# ## Task 2: adding normalization
#
# * Add batch norm (with default params) between convolution and ReLU
#   * nn.BatchNorm*d (1d for dense, 2d for conv)
#   * usually better to put them after linear/conv but before nonlinearity
# * Re-train the network with the same optimizer, it should get at least 60% validation accuracy at peak.

# %%
model = nn.Sequential()

# convolution
model.add_module('conv1', nn.Conv2d(in_channels=3, out_channels=10, kernel_size=3))
model.add_module('conv1_norm', nn.BatchNorm2d(10))
model.add_module('conv1_relu', nn.ReLU())
model.add_module('pool1', nn.MaxPool2d(2))

# reshape from "images" to flat vectors
model.add_module('flatten', Flatten())

# dense "head"
model.add_module('dense1', nn.Linear(2250, 100))
model.add_module('dense1_relu', nn.ReLU())

model.add_module('dropout1', nn.Dropout(0.1))

# dense "tail"
model.add_module('dense2', nn.Linear(100, 64))
model.add_module('dense2_relu', nn.ReLU())

model.add_module('dense3_logits', nn.Linear(64, 10)) # logits for 10 classes

# %%
opt = torch.optim.SGD(model.parameters(), lr=0.01)

train_loss = []
val_accuracy = []

# %%
import time
num_epochs = 100 # total amount of full passes over training data
batch_size = 50  # number of samples processed in one SGD iteration

for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    for X_batch, y_batch in iterate_minibatches(X_train, y_train, batch_size):
        # train on batch
        loss = compute_loss(X_batch, y_batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.data.numpy())
        
    # And a full pass over the validation data:
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in iterate_minibatches(X_val, y_val, batch_size):
        logits = model(torch.as_tensor(X_batch, dtype=torch.float32))
        y_pred = logits.max(1)[1].data.numpy()
        val_accuracy.append(np.mean(y_batch == y_pred))

    
    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss[-len(X_train) // batch_size :])))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy[-len(X_val) // batch_size :]) * 100))
# Out:
# Epoch 1 of 100 took 10.117s
#   training loss (in-iteration): 	1.895999
#   validation accuracy: 			36.11 %
# Epoch 2 of 100 took 10.059s
#   training loss (in-iteration): 	1.491270
#   validation accuracy: 			48.37 %
# Epoch 3 of 100 took 10.241s
#   training loss (in-iteration): 	1.330638
#   validation accuracy: 			48.46 %
# Epoch 4 of 100 took 10.026s
#   training loss (in-iteration): 	1.235340
#   validation accuracy: 			45.51 %
# Epoch 5 of 100 took 10.154s
#   training loss (in-iteration): 	1.160715
#   validation accuracy: 			56.26 %
# Epoch 6 of 100 took 10.219s
#   training loss (in-iteration): 	1.091486
#   validation accuracy: 			59.67 %
# Epoch 7 of 100 took 10.031s
#   training loss (in-iteration): 	1.032651
#   validation accuracy: 			61.77 %
# Epoch 8 of 100 took 10.376s
#   training loss (in-iteration): 	0.984574
#   validation accuracy: 			60.60 %
# Epoch 9 of 100 took 10.233s
#   training loss (in-iteration): 	0.931333
#   validation accuracy: 			52.05 %
# Epoch 10 of 100 took 10.316s
#   training loss (in-iteration): 	0.891249
#   validation accuracy: 			51.23 %
# Epoch 11 of 100 took 10.137s
#   training loss (in-iteration): 	0.847512
#   validation accuracy: 			61.24 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/bj/_vsd3m557t1f_thrrlbwhjn80000gn/T/ipykernel_8733/212679189.py in <cell line: 5>()
#       9     for X_batch, y_batch in iterate_minibatches(X_train, y_train, batch_size):
#      10         # train on batch
# ---> 11         loss = compute_loss(X_batch, y_batch)
#      12         loss.backward()
#      13         opt.step()
#
# /var/folders/bj/_vsd3m557t1f_thrrlbwhjn80000gn/T/ipykernel_8733/1749192806.py in compute_loss(X_batch, y_batch)
#       2     X_batch = torch.as_tensor(X_batch, dtype=torch.float32)
#       3     y_batch = torch.as_tensor(y_batch, dtype=torch.int64)
# ----> 4     logits = model(X_batch)
#       5     return F.cross_entropy(logits, y_batch).mean()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Final test (convolution + batch normalization)

# %%
model.train(False) # disable dropout / use averages for batch_norm
test_batch_acc = []
for X_batch, y_batch in iterate_minibatches(X_test, y_test, 500):
    logits = model(torch.as_tensor(X_batch, dtype=torch.float32))
    y_pred = logits.max(1)[1].data.numpy()
    test_batch_acc.append(np.mean(y_batch == y_pred))

test_accuracy = np.mean(test_batch_acc)
    
print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_accuracy * 100))

if test_accuracy * 100 > 95:
    print("Double-check, than consider applying for NIPS'17. SRSly.")
elif test_accuracy * 100 > 90:
    print("U'r freakin' amazin'!")
elif test_accuracy * 100 > 80:
    print("Achievement unlocked: 110lvl Warlock!")
elif test_accuracy * 100 > 70:
    print("Achievement unlocked: 80lvl Warlock!")
elif test_accuracy * 100 > 60:
    print("Achievement unlocked: 70lvl Warlock!")
elif test_accuracy * 100 > 50:
    print("Achievement unlocked: 60lvl Warlock!")
else:
    print("We need more magic! Follow instructons below")
# Out:
# Final results:
#   test accuracy:		62.60 %
# Achievement unlocked: 70lvl Warlock!

# %% [markdown]
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
# ## Task 3: Data Augmentation
#
# There's a powerful torch tool for image preprocessing useful to do data preprocessing and augmentation.
#
# Here's how it works: we define a pipeline that
# * makes random crops of data (augmentation)
# * randomly flips image horizontally (augmentation)
# * then normalizes it (preprocessing)

# %%
from torchvision import transforms
means = np.array((0.4914, 0.4822, 0.4465))
stds = np.array((0.2023, 0.1994, 0.2010))

transform_augment = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomRotation([-30, 30]),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
#     transforms.Normalize(means, stds),
])

# %%
from torchvision.datasets import CIFAR10
train_loader = CIFAR10("./cifar_data/", train=True, transform=transform_augment)

train_batch_gen = torch.utils.data.DataLoader(train_loader, 
                                              batch_size=50,
                                              shuffle=True,
                                              num_workers=1)

# %%
for (x_batch, y_batch) in train_batch_gen:
    
    print('X:', type(x_batch), x_batch.shape)
    print('y:', type(y_batch), y_batch.shape)
    
    for i, img in enumerate(x_batch.numpy()[:8]):
        plt.subplot(2, 4, i+1)
        plt.imshow(img.transpose([1,2,0]) * stds + means )
        
    
    raise NotImplementedError("Please use this code in your training loop")
    # TODO use this in your training loop
# Out:
# X: <class 'torch.Tensor'> torch.Size([50, 3, 32, 32])
# y: <class 'torch.Tensor'> torch.Size([50])
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /var/folders/bj/_vsd3m557t1f_thrrlbwhjn80000gn/T/ipykernel_8733/3072054105.py in <cell line: 1>()
#       9
#      10
# ---> 11     raise NotImplementedError("Please use this code in your training loop")
#      12     # TODO use this in your training loop
#
# NotImplementedError: Please use this code in your training loop

# %% [markdown]
# When testing, we don't need random crops, just normalize with same statistics.

# %%
model = nn.Sequential()

# convolution
model.add_module('conv1', nn.Conv2d(in_channels=3, out_channels=10, kernel_size=3))
# model.add_module('conv1_norm', nn.BatchNorm2d(10))
model.add_module('conv1_relu', nn.ReLU())
model.add_module('pool1', nn.MaxPool2d(2))

# reshape from "images" to flat vectors
model.add_module('flatten', Flatten())

# dense "head"
model.add_module('dense1', nn.Linear(2250, 100))
model.add_module('dense1_relu', nn.ReLU())

model.add_module('dropout1', nn.Dropout(0.1))

# dense "tail"
model.add_module('dense2', nn.Linear(100, 64))
model.add_module('dense2_relu', nn.ReLU())

model.add_module('dense3_logits', nn.Linear(64, 10)) # logits for 10 classes

# %%
transform_test = transforms.Compose([
    transforms.ToTensor(),
#     transforms.Normalize(means, stds),
])

test_loader = CIFAR10("./cifar_data/", train=False, transform=transform_test)

test_batch_gen = torch.utils.data.DataLoader(test_loader, batch_size=50, shuffle=True, num_workers=1)

# %%
opt = torch.optim.SGD(model.parameters(), lr=0.01)

train_loss = []
val_accuracy = []

# %%
import time
num_epochs = 100 # total amount of full passes over training data
batch_size = 50  # number of samples processed in one SGD iteration
# batch_size = 32

for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    for (X_batch, y_batch) in train_batch_gen:
        # train on batch
        loss = compute_loss(X_batch, y_batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.data.numpy())
        
    # And a full pass over the validation data:
    model.train(False) # disable dropout / use averages for batch_norm
#     for (X_batch, y_batch) in test_batch_gen:
    for X_batch, y_batch in iterate_minibatches(X_val, y_val, batch_size):
        logits = model(torch.as_tensor(X_batch, dtype=torch.float32))
        y_pred = logits.max(1)[1].data.numpy()
        
#         print(y_pred)
#         print(y_batch.numpy())
        val_accuracy.append(np.mean(y_batch == y_pred))
    
    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss[-len(X_train) // batch_size :])))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy[-len(X_val) // batch_size :]) * 100))
# Out:
# Epoch 1 of 100 took 30.370s
#   training loss (in-iteration): 	2.270155
#   validation accuracy: 			18.25 %
# Epoch 2 of 100 took 29.530s
#   training loss (in-iteration): 	2.091228
#   validation accuracy: 			27.77 %
# Epoch 3 of 100 took 29.312s
#   training loss (in-iteration): 	1.989644
#   validation accuracy: 			32.91 %
# Epoch 4 of 100 took 29.435s
#   training loss (in-iteration): 	1.898831
#   validation accuracy: 			34.73 %
# Epoch 5 of 100 took 29.459s
#   training loss (in-iteration): 	1.808523
#   validation accuracy: 			39.08 %
# Epoch 6 of 100 took 29.347s
#   training loss (in-iteration): 	1.752990
#   validation accuracy: 			42.35 %
# Epoch 7 of 100 took 29.621s
#   training loss (in-iteration): 	1.710058
#   validation accuracy: 			43.79 %
# Epoch 8 of 100 took 29.525s
#   training loss (in-iteration): 	1.674093
#   validation accuracy: 			44.99 %
# Epoch 9 of 100 took 29.465s
#   training loss (in-iteration): 	1.646300
#   validation accuracy: 			45.99 %
# Epoch 10 of 100 took 29.579s
#   training loss (in-iteration): 	1.612710
#   validation accuracy: 			47.45 %
# Epoch 11 of 100 took 68.856s
#   training loss (in-iteration): 	1.585352
#   validation accuracy: 			49.31 %
# Epoch 12 of 100 took 29.485s
#   training loss (in-iteration): 	1.570824
#   validation accuracy: 			49.17 %
# Epoch 13 of 100 took 29.234s
#   training loss (in-iteration): 	1.546423
#   validation accuracy: 			50.89 %
# Epoch 14 of 100 took 29.479s
#   training loss (in-iteration): 	1.525404
#   validation accuracy: 			50.80 %
# Epoch 15 of 100 took 29.289s
#   training loss (in-iteration): 	1.511600
#   validation accuracy: 			51.67 %
# Epoch 16 of 100 took 29.599s
#   training loss (in-iteration): 	1.503304
#   validation accuracy: 			52.70 %
# Epoch 17 of 100 took 29.790s
#   training loss (in-iteration): 	1.491422
#   validation accuracy: 			52.96 %
# Epoch 18 of 100 took 30.046s
#   training loss (in-iteration): 	1.479720
#   validation accuracy: 			53.85 %
# Epoch 19 of 100 took 29.625s
#   training loss (in-iteration): 	1.467604
#   validation accuracy: 			54.70 %
# Epoch 20 of 100 took 29.433s
#   training loss (in-iteration): 	1.460358
#   validation accuracy: 			54.52 %
# Epoch 21 of 100 took 29.559s
#   training loss (in-iteration): 	1.448027
#   validation accuracy: 			55.37 %
# Epoch 22 of 100 took 29.459s
#   training loss (in-iteration): 	1.445565
#   validation accuracy: 			55.77 %
# Epoch 23 of 100 took 29.393s
#   training loss (in-iteration): 	1.430645
#   validation accuracy: 			55.56 %
# Epoch 24 of 100 took 29.674s
#   training loss (in-iteration): 	1.429604
#   validation accuracy: 			56.61 %
# Epoch 25 of 100 took 29.498s
#   training loss (in-iteration): 	1.421275
#   validation accuracy: 			56.65 %
# Epoch 26 of 100 took 29.484s
#   training loss (in-iteration): 	1.418571
#   validation accuracy: 			56.26 %
# Epoch 27 of 100 took 29.310s
#   training loss (in-iteration): 	1.405609
#   validation accuracy: 			57.13 %
# Epoch 28 of 100 took 29.163s
#   training loss (in-iteration): 	1.405681
#   validation accuracy: 			57.49 %
# Epoch 29 of 100 took 29.310s
#   training loss (in-iteration): 	1.393227
#   validation accuracy: 			57.11 %
# Epoch 30 of 100 took 29.472s
#   training loss (in-iteration): 	1.390759
#   validation accuracy: 			57.80 %
# Epoch 31 of 100 took 29.412s
#   training loss (in-iteration): 	1.384515
#   validation accuracy: 			57.72 %
# Epoch 32 of 100 took 29.460s
#   training loss (in-iteration): 	1.381354
#   validation accuracy: 			58.67 %
# Epoch 33 of 100 took 29.659s
#   training loss (in-iteration): 	1.370016
#   validation accuracy: 			58.88 %
# Epoch 34 of 100 took 29.462s
#   training loss (in-iteration): 	1.369692
#   validation accuracy: 			59.23 %
# Epoch 35 of 100 took 29.486s
#   training loss (in-iteration): 	1.362056
#   validation accuracy: 			58.53 %
# Epoch 36 of 100 took 29.262s
#   training loss (in-iteration): 	1.359720
#   validation accuracy: 			59.81 %
# Epoch 37 of 100 took 29.974s
#   training loss (in-iteration): 	1.350532
#   validation accuracy: 			59.65 %
# Epoch 38 of 100 took 30.211s
#   training loss (in-iteration): 	1.348127
#   validation accuracy: 			58.49 %
# Epoch 39 of 100 took 29.506s
#   training loss (in-iteration): 	1.346850
#   validation accuracy: 			59.75 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/bj/_vsd3m557t1f_thrrlbwhjn80000gn/T/ipykernel_8733/1253048467.py in <cell line: 6>()
#      10     for (X_batch, y_batch) in train_batch_gen:
#      11         # train on batch
# ---> 12         loss = compute_loss(X_batch, y_batch)
#      13         loss.backward()
#      14         opt.step()
#
# /var/folders/bj/_vsd3m557t1f_thrrlbwhjn80000gn/T/ipykernel_8733/1749192806.py in compute_loss(X_batch, y_batch)
#       2     X_batch = torch.as_tensor(X_batch, dtype=torch.float32)
#       3     y_batch = torch.as_tensor(y_batch, dtype=torch.int64)
# ----> 4     logits = model(X_batch)
#       5     return F.cross_entropy(logits, y_batch).mean()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/pooling.py in forward(self, input)
#     160
#     161     def forward(self, input: Tensor):
# --> 162         return F.max_pool2d(input, self.kernel_size, self.stride,
#     163                             self.padding, self.dilation, ceil_mode=self.ceil_mode,
#     164                             return_indices=self.return_indices)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/_jit_internal.py in fn(*args, **kwargs)
#     421             return if_true(*args, **kwargs)
#     422         else:
# --> 423             return if_false(*args, **kwargs)
#     424
#     425     if if_true.__doc__ is None and if_false.__doc__ is not None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/functional.py in _max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode, return_indices)
#     780     if stride is None:
#     781         stride = torch.jit.annotate(List[int], [])
# --> 782     return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
#     783
#     784
#
# KeyboardInterrupt:

# %%
model.train(False) # disable dropout / use averages for batch_norm
test_batch_acc = []
for X_batch, y_batch in iterate_minibatches(X_test, y_test, 500):
# for (X_batch, y_batch) in torch.utils.data.DataLoader(test_loader, batch_size=500, shuffle=True, num_workers=1):
    logits = model(torch.as_tensor(X_batch, dtype=torch.float32))
    y_pred = logits.max(1)[1].data.numpy()
    test_batch_acc.append(np.mean(y_batch == y_pred))

test_accuracy = np.mean(test_batch_acc)
    
print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_accuracy * 100))

if test_accuracy * 100 > 95:
    print("Double-check, than consider applying for NIPS'17. SRSly.")
elif test_accuracy * 100 > 90:
    print("U'r freakin' amazin'!")
elif test_accuracy * 100 > 80:
    print("Achievement unlocked: 110lvl Warlock!")
elif test_accuracy * 100 > 70:
    print("Achievement unlocked: 80lvl Warlock!")
elif test_accuracy * 100 > 60:
    print("Achievement unlocked: 70lvl Warlock!")
elif test_accuracy * 100 > 50:
    print("Achievement unlocked: 60lvl Warlock!")
else:
    print("We need more magic! Follow instructons below")
# Out:
# Final results:
#   test accuracy:		58.22 %
# Achievement unlocked: 60lvl Warlock!

# %% [markdown]
# # Homework 2.2: The Quest For A Better Network
#
# In this assignment you will build a monster network to solve CIFAR10 image classification.
#
# This notebook is intended as a sequel to seminar 3, please give it a try if you haven't done so yet.

# %% [markdown]
# (please read it at least diagonally)
#
# * The ultimate quest is to create a network that has as high __accuracy__ as you can push it.
# * There is a __mini-report__ at the end that you will have to fill in. We recommend reading it first and filling it while you iterate.
#
# ## Grading
# * starting at zero points
# * +20% for describing your iteration path in a report below.
# * +20% for building a network that gets above 20% accuracy
# * +10% for beating each of these milestones on __TEST__ dataset:
#     * 50% (50% points)
#     * 60% (60% points)
#     * 65% (70% points)
#     * 70% (80% points)
#     * 75% (90% points)
#     * 80% (full points)
#
# ## Restrictions
# * Please do NOT use pre-trained networks for this assignment until you reach 80%.
#  * In other words, base milestones must be beaten without pre-trained nets (and such net must be present in the e-mail). After that, you can use whatever you want.
# * you __can__ use validation data for training, but you __can't'__ do anything with test data apart from running the evaluation procedure.
#
# ## Tips on what can be done:
#
#
#  * __Network size__
#    * MOAR neurons,
#    * MOAR layers, ([torch.nn docs](http://pytorch.org/docs/master/nn.html))
#
#    * Nonlinearities in the hidden layers
#      * tanh, relu, leaky relu, etc
#    * Larger networks may take more epochs to train, so don't discard your net just because it could didn't beat the baseline in 5 epochs.
#
#    * Ph'nglui mglw'nafh Cthulhu R'lyeh wgah'nagl fhtagn!
#
#
# ### The main rule of prototyping: one change at a time
#    * By now you probably have several ideas on what to change. By all means, try them out! But there's a catch: __never test several new things at once__.
#
#
# ### Optimization
#    * Training for 100 epochs regardless of anything is probably a bad idea.
#    * Some networks converge over 5 epochs, others - over 500.
#    * Way to go: stop when validation score is 10 iterations past maximum
#    * You should certainly use adaptive optimizers
#      * rmsprop, nesterov_momentum, adam, adagrad and so on.
#      * Converge faster and sometimes reach better optima
#      * It might make sense to tweak learning rate/momentum, other learning parameters, batch size and number of epochs
#    * __BatchNormalization__ (nn.BatchNorm2d) for the win!
#      * Sometimes more batch normalization is better.
#    * __Regularize__ to prevent overfitting
#      * Add some L2 weight norm to the loss function, PyTorch will do the rest
#        * Can be done manually or with weight_decay parameter of a optimizer ([for example SGD's doc](https://pytorch.org/docs/stable/optim.html#torch.optim.SGD)).
#      * Dropout (`nn.Dropout`) - to prevent overfitting
#        * Don't overdo it. Check if it actually makes your network better
#
# ### Convolution architectures
#    * This task __can__ be solved by a sequence of convolutions and poolings with batch_norm and ReLU seasoning, but you shouldn't necessarily stop there.
#    * [Inception family](https://hacktilldawn.com/2016/09/25/inception-modules-explained-and-implemented/), [ResNet family](https://towardsdatascience.com/an-overview-of-resnet-and-its-variants-5281e2f56035?gi=9018057983ca), [Densely-connected convolutions (exotic)](https://arxiv.org/abs/1608.06993), [Capsule networks (exotic)](https://arxiv.org/abs/1710.09829)
#    * Please do try a few simple architectures before you go for resnet-152.
#    * Warning! Training convolutional networks can take long without GPU. That's okay.
#      * If you are CPU-only, we still recomment that you try a simple convolutional architecture
#      * a perfect option is if you can set it up to run at nighttime and check it up at the morning.
#      * Make reasonable layer size estimates. A 128-neuron first convolution is likely an overkill.
#      * __To reduce computation__ time by a factor in exchange for some accuracy drop, try using __stride__ parameter. A stride=2 convolution should take roughly 1/4 of the default (stride=1) one.
#
#
# ### Data augmemntation
#    * getting 5x as large dataset for free is a great
#      * Zoom-in+slice = move
#      * Rotate+zoom(to remove black stripes)
#      * Add Noize (gaussian or bernoulli)
#    * Simple way to do that (if you have PIL/Image):
#      * ```from scipy.misc import imrotate,imresize```
#      * and a few slicing
#      * Other cool libraries: cv2, skimake, PIL/Pillow
#    * A more advanced way is to use torchvision transforms:
#     ```
#     transform_train = transforms.Compose([
#         transforms.RandomCrop(32, padding=4),
#         transforms.RandomHorizontalFlip(),
#         transforms.ToTensor(),
#         transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
#     ])
#     trainset = torchvision.datasets.CIFAR10(root=path_to_cifar_like_in_seminar, train=True, download=True, transform=transform_train)
#     trainloader = torch.utils.data.DataLoader(trainset, batch_size=128, shuffle=True, num_workers=2)
#
#     ```
#    * Or use this tool from Keras (requires theano/tensorflow): [tutorial](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), [docs](https://keras.io/preprocessing/image/)
#    * Stay realistic. There's usually no point in flipping dogs upside down as that is not the way you usually see them.
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```

# %%
# you might as well write your solution here :)
